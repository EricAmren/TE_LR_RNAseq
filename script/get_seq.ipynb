# %%
import pysam
GENOME = "/data2/eric/TE_LR_RNAseq/data/dmgoth101_genome_alignments/genome/dmgoth101_assembl_chrom.fasta"

# %%
# 2L_RaGOO:20942953-20943027

genome = pysam.FastaFile(GENOME)
G5A_seq = genome.fetch(reference="2L_RaGOO", start = 20942953, end = 20943027)
# print(G5A_seq)

# 4_RaGOO:1014508-1014696
pogo_seq = genome.fetch(reference="4_RaGOO", start = 1014508, end = 1014696)
# print(pogo_seq)


#2L_RaGOO 12650	17604
copia_seq = genome.fetch(reference="2L_RaGOO", start = 12650, end = 17604)
print(copia_seq)
# Out:
# ...
